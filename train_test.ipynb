# %%
# importing dependencies
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('wildfire_data_with_clusters.csv')
print(f"Data loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
display(df.head())
# Out:
# Data loaded: 9,509,925 rows × 21 columns
#     latitude  longitude    datetime Wildfire        pr      rmax      rmin  \
# 0  48.128431 -97.276685  2018-08-15       No -0.053101 -0.050631 -0.063031
# 1  48.128431 -97.276685  2018-08-16       No -0.053101 -0.049571 -0.063620
# 2  48.128431 -97.276685  2018-08-17       No -0.053101 -0.055165 -0.059797
# 3  48.128431 -97.276685  2018-08-18       No -0.050163 -0.058522 -0.060385
# 4  48.128431 -97.276685  2018-08-19       No -0.053101 -0.038028 -0.046975
#
#         sph      srad      tmmn  ...        vs        bi     fm100    fm1000  \
# 0 -0.052081 -0.021598 -0.051093  ... -0.052530 -0.048324 -0.053601 -0.053433
# 1 -0.052080 -0.026678 -0.049967  ... -0.052530 -0.048324 -0.053895 -0.053551
# 2 -0.052080 -0.025733 -0.048841  ... -0.052471 -0.048324 -0.054189 -0.053609
# 3 -0.052080 -0.028214 -0.046945  ... -0.051296 -0.071849 -0.053777 -0.053551
# 4 -0.052079 -0.084101 -0.050027  ... -0.051531 -0.047736 -0.052661 -0.053492
#
#         erc       etr       pet       vpd  Wildfire_binary  cluster_id
# 0 -0.045941 -0.050984 -0.051275 -0.051811                0           3
# 1 -0.044765 -0.050573 -0.051040 -0.051612                0           3
# 2 -0.044765 -0.051161 -0.051393 -0.051858                0           3
# 3 -0.054178 -0.049515 -0.050453 -0.051659                0           3
# 4 -0.050059 -0.052688 -0.052509 -0.052358                0           3
#
# [5 rows x 21 columns]

# %%
# separate columns into features and target
# columns related to weather conditions
weather_cols = [
    'pr','rmax','rmin','sph','srad','tmmn','tmmx','vs',
    'bi','fm100','fm1000','erc','etr','pet','vpd'
]

# columns related to geographical context
geo_cols = ['latitude', 'longitude']
cluster_col = ['cluster_id']

feature_cols = geo_cols + weather_cols + cluster_col

X = df[feature_cols]
y = df['Wildfire_binary'] # target variable indicating wildfire occurrence

# %%
# splitting based on time to prevent data leakage
cutoff_date = "2022-01-01" # around 80% give or take

train_df = df[df['datetime'] < cutoff_date]
test_df  = df[df['datetime'] >= cutoff_date]

print(f"\nTrain rows: {len(train_df):,}")
print(f" Test rows: {len(test_df):,}")
# Out:
# Train rows: 8,059,751
#  Test rows: 1,450,174

# %%
# preparing training and testing sets
X_train = train_df[feature_cols]
y_train = train_df['Wildfire_binary']

X_test = test_df[feature_cols]
y_test = test_df['Wildfire_binary']

# %%
# saving train/test split files
train_df.to_csv("wildfire_train_split.csv", index=False)
test_df.to_csv("wildfire_test_split.csv", index=False)

# %%
# Train fire counts
print(f"Training set fire counts:\n{y_train.value_counts()}")
# Test fire counts
print(f"\nTesting set fire counts:\n{y_test.value_counts()}")

# Train cluster distribution
print(f"\nTraining set cluster distribution:\n{X_train['cluster_id'].value_counts   ()}")
# Test cluster distribution
print(f"\nTesting set cluster distribution:\n{X_test['cluster_id'].value_counts()}")
# Out:
# Training set fire counts:
# Wildfire_binary
# 0    7732235
# 1     327516
# Name: count, dtype: int64
#
# Testing set fire counts:
# Wildfire_binary
# 0    1275625
# 1     174549
# Name: count, dtype: int64
#
# Training set cluster distribution:
# cluster_id
# 2    2426382
# 0    2127263
# 1    1743008
# 3    1324179
# 5     420707
# 4      18212
# Name: count, dtype: int64
#
# Testing set cluster distribution:
# cluster_id
# 2    483018
# 0    476812
# 1    277117
# 3    127221
# 5     78493
# 4      7513
# Name: count, dtype: int64
